# %%
# !wget --no-check-certificate \
    https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
    -O /tmp/Chessman-image-dataset.zip
# Out:
# --2023-12-07 08:43:38--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2023-12-07 08:43:38--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M  80.1MB/s    in 0.7s
#
# 2023-12-07 08:43:41 (80.1 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Knight', 'Bishop', 'Pawn', 'Queen', 'Rook', 'King']

# %%
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1) # set validation split

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 41s - loss: 1.9487 - accuracy: 0.1643 - val_loss: 1.7840 - val_accuracy: 0.2115 - 41s/epoch - 650ms/step
# Epoch 2/50
# 63/63 - 38s - loss: 1.7888 - accuracy: 0.1824 - val_loss: 1.7808 - val_accuracy: 0.1538 - 38s/epoch - 599ms/step
# Epoch 3/50
# 63/63 - 37s - loss: 1.7806 - accuracy: 0.2124 - val_loss: 1.7731 - val_accuracy: 0.2500 - 37s/epoch - 590ms/step
# Epoch 4/50
# 63/63 - 36s - loss: 1.7284 - accuracy: 0.2405 - val_loss: 1.7350 - val_accuracy: 0.2692 - 36s/epoch - 569ms/step
# Epoch 5/50
# 63/63 - 37s - loss: 1.7018 - accuracy: 0.2725 - val_loss: 1.7555 - val_accuracy: 0.2885 - 37s/epoch - 582ms/step
# Epoch 6/50
# 63/63 - 40s - loss: 1.6380 - accuracy: 0.3206 - val_loss: 1.6210 - val_accuracy: 0.3269 - 40s/epoch - 635ms/step
# Epoch 7/50
# 63/63 - 38s - loss: 1.6436 - accuracy: 0.3487 - val_loss: 1.6435 - val_accuracy: 0.3846 - 38s/epoch - 597ms/step
# Epoch 8/50
# 63/63 - 37s - loss: 1.5985 - accuracy: 0.3467 - val_loss: 1.5346 - val_accuracy: 0.5000 - 37s/epoch - 582ms/step
# Epoch 9/50
# 63/63 - 40s - loss: 1.5658 - accuracy: 0.3768 - val_loss: 1.6132 - val_accuracy: 0.3846 - 40s/epoch - 630ms/step
# Epoch 10/50
# 63/63 - 36s - loss: 1.5207 - accuracy: 0.3747 - val_loss: 1.6551 - val_accuracy: 0.2308 - 36s/epoch - 576ms/step
# Epoch 11/50
# 63/63 - 38s - loss: 1.4560 - accuracy: 0.4028 - val_loss: 1.6111 - val_accuracy: 0.3654 - 38s/epoch - 596ms/step
# Epoch 12/50
# 63/63 - 37s - loss: 1.4276 - accuracy: 0.4409 - val_loss: 1.7395 - val_accuracy: 0.2885 - 37s/epoch - 589ms/step
# Epoch 13/50
# 63/63 - 37s - loss: 1.3384 - accuracy: 0.4749 - val_loss: 1.8832 - val_accuracy: 0.2692 - 37s/epoch - 581ms/step
# Epoch 14/50
# 63/63 - 36s - loss: 1.3248 - accuracy: 0.4810 - val_loss: 1.5455 - val_accuracy: 0.3846 - 36s/epoch - 566ms/step
# Epoch 15/50
# 63/63 - 36s - loss: 1.3118 - accuracy: 0.4870 - val_loss: 1.6427 - val_accuracy: 0.4423 - 36s/epoch - 568ms/step
# Epoch 16/50
# 63/63 - 40s - loss: 1.2341 - accuracy: 0.5070 - val_loss: 1.7035 - val_accuracy: 0.4231 - 40s/epoch - 629ms/step
# Epoch 17/50
# 63/63 - 36s - loss: 1.2233 - accuracy: 0.5230 - val_loss: 1.6400 - val_accuracy: 0.4038 - 36s/epoch - 575ms/step
# Epoch 18/50
# 63/63 - 36s - loss: 1.1587 - accuracy: 0.5591 - val_loss: 1.5825 - val_accuracy: 0.3654 - 36s/epoch - 566ms/step
# Epoch 19/50
# 63/63 - 38s - loss: 1.1761 - accuracy: 0.5451 - val_loss: 1.8843 - val_accuracy: 0.3077 - 38s/epoch - 608ms/step
# Epoch 20/50
# 63/63 - 36s - loss: 1.0892 - accuracy: 0.6012 - val_loss: 1.6597 - val_accuracy: 0.4231 - 36s/epoch - 570ms/step
# Epoch 21/50
# 63/63 - 36s - loss: 1.0260 - accuracy: 0.6212 - val_loss: 1.5460 - val_accuracy: 0.4615 - 36s/epoch - 575ms/step
# Epoch 22/50
# 63/63 - 36s - loss: 1.0412 - accuracy: 0.6052 - val_loss: 1.6360 - val_accuracy: 0.4231 - 36s/epoch - 576ms/step
# Epoch 23/50
# 63/63 - 36s - loss: 0.9662 - accuracy: 0.6553 - val_loss: 1.7605 - val_accuracy: 0.4423 - 36s/epoch - 565ms/step
# Epoch 24/50
# 63/63 - 37s - loss: 0.9768 - accuracy: 0.6052 - val_loss: 1.6963 - val_accuracy: 0.4038 - 37s/epoch - 591ms/step
# Epoch 25/50
# 63/63 - 39s - loss: 0.9107 - accuracy: 0.6633 - val_loss: 1.5177 - val_accuracy: 0.5385 - 39s/epoch - 622ms/step
# Epoch 26/50
# 63/63 - 37s - loss: 0.9948 - accuracy: 0.6112 - val_loss: 1.6393 - val_accuracy: 0.4038 - 37s/epoch - 580ms/step
# Epoch 27/50
# 63/63 - 36s - loss: 0.8342 - accuracy: 0.6974 - val_loss: 1.6454 - val_accuracy: 0.4423 - 36s/epoch - 577ms/step
# Epoch 28/50
# 63/63 - 36s - loss: 0.9083 - accuracy: 0.6493 - val_loss: 1.7379 - val_accuracy: 0.3077 - 36s/epoch - 565ms/step
# Epoch 29/50
# 63/63 - 38s - loss: 0.8627 - accuracy: 0.7034 - val_loss: 1.6118 - val_accuracy: 0.4423 - 38s/epoch - 604ms/step
# Epoch 30/50
# 63/63 - 38s - loss: 0.8076 - accuracy: 0.7435 - val_loss: 1.8555 - val_accuracy: 0.4423 - 38s/epoch - 597ms/step
# Epoch 31/50
# 63/63 - 35s - loss: 0.7102 - accuracy: 0.7515 - val_loss: 2.0873 - val_accuracy: 0.4423 - 35s/epoch - 562ms/step
# Epoch 32/50
# 63/63 - 37s - loss: 0.8006 - accuracy: 0.7375 - val_loss: 1.5665 - val_accuracy: 0.5000 - 37s/epoch - 592ms/step
# Epoch 33/50
# 63/63 - 36s - loss: 0.7638 - accuracy: 0.7375 - val_loss: 1.8298 - val_accuracy: 0.4423 - 36s/epoch - 570ms/step
# Epoch 34/50
# 63/63 - 36s - loss: 0.6144 - accuracy: 0.7675 - val_loss: 1.7181 - val_accuracy: 0.4423 - 36s/epoch - 576ms/step
# Epoch 35/50
# 63/63 - 39s - loss: 0.7194 - accuracy: 0.7455 - val_loss: 1.5623 - val_accuracy: 0.5192 - 39s/epoch - 615ms/step
# Epoch 36/50
# 63/63 - 37s - loss: 0.6810 - accuracy: 0.7415 - val_loss: 1.7652 - val_accuracy: 0.4038 - 37s/epoch - 586ms/step
# Epoch 37/50
# 63/63 - 37s - loss: 0.6167 - accuracy: 0.7776 - val_loss: 1.4471 - val_accuracy: 0.4423 - 37s/epoch - 582ms/step
# Epoch 38/50
# 63/63 - 38s - loss: 0.5919 - accuracy: 0.7756 - val_loss: 1.9452 - val_accuracy: 0.4038 - 38s/epoch - 605ms/step
# Epoch 39/50
# 63/63 - 35s - loss: 0.5700 - accuracy: 0.7956 - val_loss: 2.1965 - val_accuracy: 0.3846 - 35s/epoch - 559ms/step
# Epoch 40/50
# 63/63 - 35s - loss: 0.5985 - accuracy: 0.7796 - val_loss: 2.0797 - val_accuracy: 0.4038 - 35s/epoch - 563ms/step
# Epoch 41/50
# 63/63 - 36s - loss: 0.5881 - accuracy: 0.7796 - val_loss: 2.0954 - val_accuracy: 0.5000 - 36s/epoch - 573ms/step
# Epoch 42/50
# 63/63 - 38s - loss: 0.4729 - accuracy: 0.8337 - val_loss: 2.0769 - val_accuracy: 0.4423 - 38s/epoch - 601ms/step
# Epoch 43/50
# 63/63 - 35s - loss: 0.5065 - accuracy: 0.8257 - val_loss: 1.9841 - val_accuracy: 0.4808 - 35s/epoch - 561ms/step
# Epoch 44/50
# 63/63 - 39s - loss: 0.4759 - accuracy: 0.8317 - val_loss: 1.9959 - val_accuracy: 0.4038 - 39s/epoch - 615ms/step
# Epoch 45/50
# 63/63 - 36s - loss: 0.5061 - accuracy: 0.8056 - val_loss: 1.8345 - val_accuracy: 0.4808 - 36s/epoch - 568ms/step
# Epoch 46/50
# 63/63 - 37s - loss: 0.4818 - accuracy: 0.8176 - val_loss: 1.5936 - val_accuracy: 0.5769 - 37s/epoch - 589ms/step
# Epoch 47/50
# 63/63 - 37s - loss: 0.4850 - accuracy: 0.8216 - val_loss: 1.8785 - val_accuracy: 0.5192 - 37s/epoch - 581ms/step
# Epoch 48/50
# 63/63 - 35s - loss: 0.4157 - accuracy: 0.8557 - val_loss: 1.8210 - val_accuracy: 0.4231 - 35s/epoch - 560ms/step
# Epoch 49/50
# 63/63 - 35s - loss: 0.4456 - accuracy: 0.8437 - val_loss: 1.6381 - val_accuracy: 0.5192 - 35s/epoch - 563ms/step
# Epoch 50/50
# 63/63 - 37s - loss: 0.3991 - accuracy: 0.8697 - val_loss: 1.8861 - val_accuracy: 0.3654 - 37s/epoch - 590ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

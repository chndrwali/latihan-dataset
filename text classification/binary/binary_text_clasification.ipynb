# %%
import pandas as pd
df = pd.read_csv('yelp_labelled.txt', names=['sentence', 'label'], sep='\t')

# %%
df.tail()
# Out:
#                                               sentence  label
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %%
from sklearn.model_selection import train_test_split
kalimat = df['sentence'].values
y = df['label'].values
kalimat_latih, kalimat_test, y_latih, y_test = train_test_split(kalimat, y, test_size=0.2)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=250, oov_token='x')
tokenizer.fit_on_texts(kalimat_latih)
tokenizer.fit_on_texts(kalimat_test)

sekuens_latih = tokenizer.texts_to_sequences(kalimat_latih)
sekuens_test = tokenizer.texts_to_sequences(kalimat_test)

padded_latih = pad_sequences(sekuens_latih, maxlen=20)
padded_test = pad_sequences(sekuens_test, maxlen=20)

# %%
import tensorflow as tf
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(250, 16, input_length=20),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
num_epochs = 30
history = model.fit(padded_latih, y_latih, epochs=num_epochs,
                    validation_data=(padded_test, y_test), verbose=2)
# Out:
# Epoch 1/30
# 25/25 - 1s - loss: 0.6928 - accuracy: 0.5138 - val_loss: 0.6931 - val_accuracy: 0.4600 - 974ms/epoch - 39ms/step
# Epoch 2/30
# 25/25 - 0s - loss: 0.6905 - accuracy: 0.5337 - val_loss: 0.6906 - val_accuracy: 0.5950 - 69ms/epoch - 3ms/step
# Epoch 3/30
# 25/25 - 0s - loss: 0.6873 - accuracy: 0.6550 - val_loss: 0.6863 - val_accuracy: 0.6500 - 66ms/epoch - 3ms/step
# Epoch 4/30
# 25/25 - 0s - loss: 0.6820 - accuracy: 0.6888 - val_loss: 0.6818 - val_accuracy: 0.6650 - 56ms/epoch - 2ms/step
# Epoch 5/30
# 25/25 - 0s - loss: 0.6742 - accuracy: 0.7050 - val_loss: 0.6721 - val_accuracy: 0.6950 - 53ms/epoch - 2ms/step
# Epoch 6/30
# 25/25 - 0s - loss: 0.6610 - accuracy: 0.7262 - val_loss: 0.6608 - val_accuracy: 0.7000 - 70ms/epoch - 3ms/step
# Epoch 7/30
# 25/25 - 0s - loss: 0.6415 - accuracy: 0.7600 - val_loss: 0.6433 - val_accuracy: 0.7100 - 68ms/epoch - 3ms/step
# Epoch 8/30
# 25/25 - 0s - loss: 0.6160 - accuracy: 0.7862 - val_loss: 0.6254 - val_accuracy: 0.7150 - 68ms/epoch - 3ms/step
# Epoch 9/30
# 25/25 - 0s - loss: 0.5847 - accuracy: 0.8050 - val_loss: 0.6049 - val_accuracy: 0.7150 - 69ms/epoch - 3ms/step
# Epoch 10/30
# 25/25 - 0s - loss: 0.5500 - accuracy: 0.8100 - val_loss: 0.5845 - val_accuracy: 0.7450 - 67ms/epoch - 3ms/step
# Epoch 11/30
# 25/25 - 0s - loss: 0.5160 - accuracy: 0.8200 - val_loss: 0.5747 - val_accuracy: 0.7300 - 58ms/epoch - 2ms/step
# Epoch 12/30
# 25/25 - 0s - loss: 0.4824 - accuracy: 0.8288 - val_loss: 0.5483 - val_accuracy: 0.7500 - 53ms/epoch - 2ms/step
# Epoch 13/30
# 25/25 - 0s - loss: 0.4529 - accuracy: 0.8413 - val_loss: 0.5416 - val_accuracy: 0.7550 - 53ms/epoch - 2ms/step
# Epoch 14/30
# 25/25 - 0s - loss: 0.4258 - accuracy: 0.8500 - val_loss: 0.5225 - val_accuracy: 0.7350 - 70ms/epoch - 3ms/step
# Epoch 15/30
# 25/25 - 0s - loss: 0.4036 - accuracy: 0.8450 - val_loss: 0.5196 - val_accuracy: 0.7650 - 75ms/epoch - 3ms/step
# Epoch 16/30
# 25/25 - 0s - loss: 0.3845 - accuracy: 0.8575 - val_loss: 0.5090 - val_accuracy: 0.7300 - 60ms/epoch - 2ms/step
# Epoch 17/30
# 25/25 - 0s - loss: 0.3670 - accuracy: 0.8587 - val_loss: 0.5050 - val_accuracy: 0.7550 - 57ms/epoch - 2ms/step
# Epoch 18/30
# 25/25 - 0s - loss: 0.3531 - accuracy: 0.8612 - val_loss: 0.5036 - val_accuracy: 0.7500 - 55ms/epoch - 2ms/step
# Epoch 19/30
# 25/25 - 0s - loss: 0.3404 - accuracy: 0.8687 - val_loss: 0.5030 - val_accuracy: 0.7500 - 58ms/epoch - 2ms/step
# Epoch 20/30
# 25/25 - 0s - loss: 0.3307 - accuracy: 0.8800 - val_loss: 0.5061 - val_accuracy: 0.7600 - 56ms/epoch - 2ms/step
# Epoch 21/30
# 25/25 - 0s - loss: 0.3232 - accuracy: 0.8775 - val_loss: 0.5080 - val_accuracy: 0.7850 - 70ms/epoch - 3ms/step
# Epoch 22/30
# 25/25 - 0s - loss: 0.3143 - accuracy: 0.8825 - val_loss: 0.5023 - val_accuracy: 0.7600 - 53ms/epoch - 2ms/step
# Epoch 23/30
# 25/25 - 0s - loss: 0.3063 - accuracy: 0.8850 - val_loss: 0.5037 - val_accuracy: 0.7550 - 54ms/epoch - 2ms/step
# Epoch 24/30
# 25/25 - 0s - loss: 0.3116 - accuracy: 0.8637 - val_loss: 0.5317 - val_accuracy: 0.7900 - 55ms/epoch - 2ms/step
# Epoch 25/30
# 25/25 - 0s - loss: 0.2954 - accuracy: 0.8800 - val_loss: 0.5089 - val_accuracy: 0.7550 - 57ms/epoch - 2ms/step
# Epoch 26/30
# 25/25 - 0s - loss: 0.2903 - accuracy: 0.8838 - val_loss: 0.5124 - val_accuracy: 0.7500 - 72ms/epoch - 3ms/step
# Epoch 27/30
# 25/25 - 0s - loss: 0.2835 - accuracy: 0.8913 - val_loss: 0.5188 - val_accuracy: 0.8000 - 57ms/epoch - 2ms/step
# Epoch 28/30
# 25/25 - 0s - loss: 0.2795 - accuracy: 0.8888 - val_loss: 0.5184 - val_accuracy: 0.7700 - 68ms/epoch - 3ms/step
# Epoch 29/30
# 25/25 - 0s - loss: 0.2756 - accuracy: 0.8938 - val_loss: 0.5225 - val_accuracy: 0.7900 - 66ms/epoch - 3ms/step
# Epoch 30/30
# 25/25 - 0s - loss: 0.2707 - accuracy: 0.8950 - val_loss: 0.5265 - val_accuracy: 0.7750 - 66ms/epoch - 3ms/step
